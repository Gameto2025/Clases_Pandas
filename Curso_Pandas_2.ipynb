# %% [markdown]
# <a href="https://colab.research.google.com/github/Gameto2025/Clases_Pandas/blob/main/Curso_Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AULA 1 : LEYENDO ARCHIVOS CSV

# %% [markdown]
# ### Importando archivos csv

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
datos_1 = pd.read_csv('superstore_data_punto_coma.csv')

# %%
datos_1.head()
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %% [markdown]
# ###Parametros de la funcion read_csv

# %%
datos_1 = pd.read_csv('superstore_data_punto_coma.csv',sep=';')

# %%
datos_1.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
#nrows, para ver un numero de filas

datos = pd.read_csv('superstore_data.csv',nrows=5)
datos
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
# Uso de usecols, para filtrar por el nombre de la columna
datos_seleccion = pd.read_csv('superstore_data.csv',usecols= ['Id','Year_Birth','Income'])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
# Uso de usecols, para filtrar usando la posicion de la columna.

datos_seleccion = pd.read_csv('superstore_data.csv',usecols= [0,1,4])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## Guardando el archivo final

# %%
datos_seleccion.to_csv('clientes_mercado.csv')

# %%
clientes_mercado= pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
# Uso de index, para evitar que se repita el index al exportar el archivo

datos_seleccion.to_csv('datos_mercado.csv',index=False)

# %%
datos_mercado= pd.read_csv('datos_mercado.csv')
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## CLASE DOS

# %% [markdown]
# ### Trabajando con Excel.

# %%
archivo = '/emisiones_CO2.xlsx'

df = pd.read_excel(archivo)

df.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
 # Para saber cuantas hojas tiene el libro de excel
 pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# ###Parametros de la funcion read_excel

# %%
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')

# %%
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
fuentes = pd.read_excel(archivo, sheet_name='fuentes')

# %%
fuentes.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
#                     Quema   Otros  \
# 63099  CDIAC 2022 and GCP  [NONE]
# 63100  CDIAC 2022 and GCP  [NONE]
# 63101  CDIAC 2022 and GCP  [NONE]
# 63102  CDIAC 2022 and GCP  [NONE]
# 63103  CDIAC 2022 and GCP  [NONE]
#
#                                               Per Capita
# 63099  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63100  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63101  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63102  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63103  CDIAC 2022, BP, Sum of countries, and UN popul...

# %%
intervalo= pd.read_excel(archivo, sheet_name='emisiones_C02',usecols='A:D')

# %%
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalo_2= pd.read_excel(archivo, sheet_name='emisiones_C02',nrows=10)
intervalo_2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750      0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751      0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752      0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753      0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754      0     NaN     NaN  NaN      NaN
# 5  Afganistán                AFG  1755      0     NaN     NaN  NaN      NaN
# 6  Afganistán                AFG  1756      0     NaN     NaN  NaN      NaN
# 7  Afganistán                AFG  1757      0     NaN     NaN  NaN      NaN
# 8  Afganistán                AFG  1758      0     NaN     NaN  NaN      NaN
# 9  Afganistán                AFG  1759      0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN
# 5    NaN    NaN         NaN
# 6    NaN    NaN         NaN
# 7    NaN    NaN         NaN
# 8    NaN    NaN         NaN
# 9    NaN    NaN         NaN

# %% [markdown]
# ###Escribiendo archivos Excel

# %%
intervalo.to_excel('co2_percapita.xlsx',index=False)

# %%
pd.read_excel('co2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ## Importando archivos Excel  de Google Sheets

# %%
#Leyendo datos de google sheets
url= https://docs.google.com/spreadsheets/d/1mRsV8OYjogOx_6neuNbboxvJaRpySydVN7mn6zBOn0I/edit?usp=sharing
# Out:
#   File "<ipython-input-83-a4883c78b66a>", line 2
#     url= https://docs.google.com/spreadsheets/d/1mRsV8OYjogOx_6neuNbboxvJaRpySydVN7mn6zBOn0I/edit?usp=sharing
#                                                 ^
# SyntaxError: invalid decimal literal

# %%
sheet_id = '1mRsV8OYjogOx_6neuNbboxvJaRpySydVN7mn6zBOn0I'

# %%
# Se debe agregar gviz/tq para que pueda conectarse la planilla excel con Colab
#  Se puede reemplazar el id por el shhet_id que se guardo anteriormente
# se debe agregar  luego de gvz/tq ?tqx=out:csv, es el formatto de salida del link y finalmente se agrega &sheet

url= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2_sheets = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-75-df3caaa1f514> in <cell line: 0>()
# ----> 1 datos_co2_sheets = pd.read_csv(url)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     726
#     727     # open URLs
# --> 728     ioargs = _get_filepath_or_buffer(
#     729         path_or_buf,
#     730         encoding=encoding,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382         # assuming storage_options is to be interpreted as headers
#     383         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384         with urlopen(req_info) as req:
#     385             content_encoding = req.headers.get("Content-Encoding", None)
#     386             if content_encoding == "gzip":
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     287     import urllib.request
#     288
# --> 289     return urllib.request.urlopen(*args, **kwargs)
#     290
#     291
#
# /usr/lib/python3.11/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.11/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.11/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.11/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.11/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 410: Gone

# %%
# para ir a una pagina determinada del libro

sheet_id = '1mRsV8OYjogOx_6neuNbboxvJaRpySydVN7mn6zBOn0I'

shhet:name = 'emisiones_percapita'

url_percapita= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-6f1060ab4f85> in <cell line: 0>()
#       3 sheet_id = '1mRsV8OYjogOx_6neuNbboxvJaRpySydVN7mn6zBOn0I'
#       4
# ----> 5 shhet:name = 'emisiones_percapita'
#       6
#       7 url_percapita= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
#
# NameError: name 'name' is not defined

# %%
percapita_sheets= pd.read:csv(url_percapita)
# Out:
#   File "<ipython-input-79-b566039ef37c>", line 1
#     percapita_sheets= pd.read:csv(url_percapita)
#                              ^
# SyntaxError: invalid syntax

# %%
percapita_sheets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-95bb04220f69> in <cell line: 0>()
# ----> 1 percapita_sheets
#
# NameError: name 'percapita_sheets' is not defined

# %%
#Para ir a la hoja fuentes
sheet_id = '1mRsV8OYjogOx_6neuNbboxvJaRpySydVN7mn6zBOn0I'

shhet:name = 'fuentes'

url_fuentes= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fuentes_sheets= pd.read_csv(url_fuentes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-3239bbf616af> in <cell line: 0>()
# ----> 1 fuentes_sheets= pd.read_csv(url_fuentes)
#
# NameError: name 'url_fuentes' is not defined

# %%
fuentes_sheets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-f33d54e062b7> in <cell line: 0>()
# ----> 1 fuentes_sheets
#
# NameError: name 'fuentes_sheets' is not defined

# %% [markdown]
# ##CLASE TRES  LEYENDO ARCHIVOS JSON

# %% [markdown]
# ####Importando archivos JSON

# %%
# Solo para leer archivos sin informacion anidada

import pandas as pd
datos_pacientes= pd.read_json('/pacientes.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-84-7f37dd905711> in <cell line: 0>()
#       2
#       3 import pandas as pd
# ----> 4 datos_pacientes= pd.read_json('/pacientes.json')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902             self.data = filepath_or_buffer
#     903         elif self.engine == "ujson":
# --> 904             data = self._get_data_from_filepath(filepath_or_buffer)
#     905             self.data = self._preprocess_data(data)
#     906
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     958             and not file_exists(filepath_or_buffer)
#     959         ):
# --> 960             raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961         else:
#     962             warnings.warn(
#
# FileNotFoundError: File /pacientes.json does not exist

# %%
datos_pacientes

# %%
# Archivo con informacion anidada

datos_pacientes2= pd.read_json('/pacientes_2.json')

# %%
datos_pacientes2

# %%
# Uso de normalize para extraer la info de archivos anidados en un dataframe.

df_normalizado = pd.json_normalize(datos_pacientes2['Pacientes'])

# %%
df_normalizado

# %%
df_normalizado.to_json('historico_pacientes_normalizados.json')

# %%
pd.read_json('historico_pacientes_normalizados.json')

# %% [markdown]
# ## CLASE CUATRO LEYENDO HTML e XML

# %% [markdown]
# ###Importando paginas web

# %%
import pandas as pd

# %%
datos_html = pd.read_html('peliculas_wikipedia.html')

# %%
datos_html

# %%
type(datos_html)

# %%
len(datos_html)

# %%
top_peliculas= datos_html[1]

# %%
top_peliculas

# %% [markdown]
# ### Escribiendo archivos html

# %%
top_peliculas.to_html('top_peliculas.html',index=False)

# %%
top_peliculas

# %%
top_peliculas.to_csv('top_peliculas_1998.csv',index=False)

# %%
datos= pd.read_csv('top_peliculas_1998.csv')
datos.head()

# %% [markdown]
# ### Archivos XML

# %%
import pandas as pd


datos_imdb= pd.read_xml('imdb_top_1000.xml')

# %%
datos_imdb.head(3)

# %%
datos_imdb.to_xml('peliculas_imdb.xml',index=False)

# %% [markdown]
# ### BASES DE DATOS

# %% [markdown]
# ### Creando un Banco de Datos Local

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ###Escribiendo en una base de datos

# %%
import pandas as pd

# %%
archivo = 'clientes_banco.csv'
datos = pd.read_csv(archivo)
datos

# %%
# Se transforma a dataframe y se crea la tabla clientes de sql.

datos.to_sql('clientes', engine, index=False)

# %%
inspeccion= inspect(engine)

# %%
print(inspeccion.get_table_names())

# %% [markdown]
# ##Leyendo una consulta SQL

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renta = "Empleado"'

# %%
empleados = pd.read_sql(sql=text(query), con= engine.connect())

# %%
empleados

# %%
empleados.to_sql('empleados', con = engine.connect(), index=False)

# %%
pd.read_sql_table('empleados', con= engine.connect())

# %%
pd.read_sql_table('empleados', con= engine.connect(), columns=['ID_Cliente','Grado_estudio','Rendimiento_anual'])

# %% [markdown]
# ### Actualizando un banco de datos

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con= engine.connect())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1963                 if not evt_handled:
# -> 1964                     self.dialect.do_execute(
#    1965                         cursor, str_statement, effective_parameters, context
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     944     def do_execute(self, cursor, statement, parameters, context=None):
# --> 945         cursor.execute(statement, parameters)
#     946
#
# OperationalError: no such table: clientes
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-93-1155b9551808> in <cell line: 0>()
# ----> 1 pd.read_sql(sql=text(query), con= engine.connect())
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     732             )
#     733         else:
# --> 734             return pandas_sql.read_query(
#     735                 sql,
#     736                 index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1834
#    1835         """
# -> 1836         result = self.execute(sql, params)
#    1837         columns = result.keys()
#    1838
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    1658         if isinstance(sql, str):
#    1659             return self.con.exec_driver_sql(sql, *args)
# -> 1660         return self.con.execute(sql, *args)
#    1661
#    1662     def read_table(
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1414             raise exc.ObjectNotExecutableError(statement) from err
#    1415         else:
# -> 1416             return meth(
#    1417                 self,
#    1418                 distilled_parameters,
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, distilled_params, execution_options)
#     521             if TYPE_CHECKING:
#     522                 assert isinstance(self, Executable)
# --> 523             return connection._execute_clauseelement(
#     524                 self, distilled_params, execution_options
#     525             )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1636             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637         )
# -> 1638         ret = self._execute_context(
#    1639             dialect,
#    1640             dialect.execution_ctx_cls._init_compiled,
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841             return self._exec_insertmany_context(dialect, context)
#    1842         else:
# -> 1843             return self._exec_single_context(
#    1844                 dialect, context, statement, parameters
#    1845             )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1981
#    1982         except BaseException as e:
# -> 1983             self._handle_dbapi_exception(
#    1984                 e, str_statement, effective_parameters, cursor, context
#    1985             )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350             elif should_wrap:
#    2351                 assert sqlalchemy_exception is not None
# -> 2352                 raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353             else:
#    2354                 assert exc_info[1] is not None
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1962                             break
#    1963                 if not evt_handled:
# -> 1964                     self.dialect.do_execute(
#    1965                         cursor, str_statement, effective_parameters, context
#    1966                     )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     943
#     944     def do_execute(self, cursor, statement, parameters, context=None):
# --> 945         cursor.execute(statement, parameters)
#     946
#     947     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: clientes
# [SQL: SELECT * FROM clientes]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Borrando registros
from sqlalchemy.exc import SQLAlchemyError
query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
try:
  r_set= engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("# Registros Borrados:", r_set.rowcount)
# Out:
# (sqlite3.OperationalError) no such table: clientes
# [SQL: DELETE FROM clientes WHERE ID_Cliente=5008804]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
pd.read_sql_table('clientes', con= engine.connect())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-5f00af7dd797> in <cell line: 0>()
# ----> 1 pd.read_sql_table('clientes', con= engine.connect())
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize, dtype_backend)
#     384     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     385         if not pandas_sql.has_table(table_name):
# --> 386             raise ValueError(f"Table {table_name} not found")
#     387
#     388         table = pandas_sql.read_table(
#
# ValueError: Table clientes not found

# %%
# actualizando registro

from sqlalchemy.exc import SQLAlchemyError
query = "UPDATE clientes SET Grado_estudio= 'Nivel superior' WHERE ID_Cliente=5008808"
try:
  r_set= engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("# Registros Actualizados:", r_set.rowcount)
# Out:
# (sqlite3.OperationalError) no such table: clientes
# [SQL: UPDATE clientes SET Grado_estudio= 'Nivel superior' WHERE ID_Cliente=5008808]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
pd.read_sql_table('clientes', con= engine.connect())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-5f00af7dd797> in <cell line: 0>()
# ----> 1 pd.read_sql_table('clientes', con= engine.connect())
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize, dtype_backend)
#     384     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     385         if not pandas_sql.has_table(table_name):
# --> 386             raise ValueError(f"Table {table_name} not found")
#     387
#     388         table = pandas_sql.read_table(
#
# ValueError: Table clientes not found

# %%
inspector= inspect(engine)
print (inspector.get_table_names())
# Out:
# []
