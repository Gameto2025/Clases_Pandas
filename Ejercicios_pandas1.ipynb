# %% [markdown]
# <a href="https://colab.research.google.com/github/Gameto2025/Clases_Pandas/blob/main/Ejercicios_pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url= 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

pd.read_csv(url)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos_alumnos= pd.read_csv(url)
datos_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos_alumnos.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
datos_alumnos['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
datos_alumnos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# # **EJERCICIO CLASE DOS**

# %% [markdown]
# El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:
#
# 1.Calcular el promedio de habitaciones por departamento.
#
# 2.Verificar cuántas colonias únicas existen en nuestra base de datos.
#
# 3.Analizar qué colonias tienen el promedio de alquiler más alto.
#
# 4. Crear un gráfico de barras horizontales que muestre las 5 colonias con los
#     promedios de alquiler más altos.

# %%
import pandas as pd
url ='https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
datos= pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %% [markdown]
# # **1. Promedio de habitaciones por departamento**

# %%
# Hacer filtrado  de los Departamentos

df = datos.query('Tipo == "Departamento"')

df
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %% [markdown]
# El promedio de habitaciones por departamento es de 2.5

# %% [markdown]
# # **2.Verificar cuántas colonias únicas existen en nuestra base de datos.\**

# %%
datos['Colonia'].nunique()
# Out:
# 88

# %% [markdown]
# Existe 88 colonias unicas en la base de datos

# %% [markdown]
# # **3.Analizar qué colonias tienen el promedio de alquiler más alto.**

# %%
df_colonias= datos.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)

df_colonias
# Out:
#                               Valor
# Colonia
# San Juan Xalpa        420926.739130
# Nativitas             244684.395062
# La Merced             213292.770833
# Santa Marta Acatitla  166048.105263
# Villa de Cortés       135737.411765
# ...                             ...
# Álvaro Obregón          3048.281250
# San José Insurgentes    2660.000000
# El Rodeo                2586.111111
# Tláhuac                 2481.818182
# Las Aguilas             2222.500000
#
# [88 rows x 1 columns]

# %% [markdown]
# ##4. Crear un gráfico de barras horizontales que muestre las 5 colonias con los  promedios de alquiler más altos.

# %%
# Seleccionar las 5 colonias con los promedios de alquiler más altos
top_5_colonias = df_colonias.head(5)


top_5_colonias.plot(kind='barh', figsize=(10,8), color='blue');

# %% [markdown]
# ## EJERCICIO CLASE TRES

# %%
import pandas as pd

url= 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

pd.read_csv(url)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# Basándonos en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.

# %% [markdown]
# ### Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

# %%
alumnos= pd.read_csv(url)
alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
alumnos['Nota'].mean()
# Out:
# np.float64(6.841666666666666)

# %%
alumnos['Nota'] = alumnos['Nota'].fillna(alumnos['Nota'].mean())

# %%
alumnos
# Out:
#       Nombre  Edad       Nota   Aprobado
# 0    Alberto    20   7.500000       True
# 1        Ana    18   6.841667      False
# 2     Camila    27   2.500000      False
# 3      David    18   5.000000      False
# 4      Brian    21  10.000000       True
# 5      Bruna    23   6.841667      False
# 6    Daniela    21   7.000000       True
# 7     Carlos    19   6.000000      False
# 8     Alicia    35   5.600000      False
# 9     Victor    28   6.841667      False
# 10    Danilo    21   6.841667      False
# 11   Ignacio    24   4.500000      False
# 12  Stephany    26  10.000000       True
# 13    Miriam    25   9.000000       True
# 14     Pablo    37   6.841667      False
# 15    Milena    29   7.000000       True
# 16     Lucas    33   6.841667      False
# 17     Nadia    34   8.000000  Verdadero

# %% [markdown]
# ###Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
alumnos.query("Nombre=='Alicia' | Nombre=='Carlos'").index
# Out:
# Index([7, 8], dtype='int64')

# %%
#Guarda el filtro de indices en alumnos_remover

alumnos_remover = alumnos.query("Nombre == 'Alicia' | Nombre == 'Carlos'").index

# %%
alumnos.drop(alumnos_remover,inplace=True)

alumnos
# Out:
#       Nombre  Edad       Nota   Aprobado
# 0    Alberto    20   7.500000       True
# 1        Ana    18   6.841667      False
# 2     Camila    27   2.500000      False
# 3      David    18   5.000000      False
# 4      Brian    21  10.000000       True
# 5      Bruna    23   6.841667      False
# 6    Daniela    21   7.000000       True
# 9     Victor    28   6.841667      False
# 10    Danilo    21   6.841667      False
# 11   Ignacio    24   4.500000      False
# 12  Stephany    26  10.000000       True
# 13    Miriam    25   9.000000       True
# 14     Pablo    37   6.841667      False
# 15    Milena    29   7.000000       True
# 16     Lucas    33   6.841667      False
# 17     Nadia    34   8.000000  Verdadero

# %% [markdown]
# ###Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
alumnos_aprobados= alumnos.query('Nota >= 7')
alumnos_aprobados
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# ###Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

# %%
alumnos_aprobados.to_csv('alumnos_.csv')

# %% [markdown]
# ###Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.

# %%
alumnos_aprobados.loc[:,'Nota'] = alumnos_aprobados['Nota'].replace(7,8)
alumnos_aprobados
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   8.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   8.0       True
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# # **EJERCICIOS CUATRO**

# %% [markdown]
# ###Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
alumnos['Puntos_extras'] = alumnos['Nota'] * 0.4
alumnos
# Out:
#       Nombre  Edad       Nota   Aprobado  Puntos_extras
# 0    Alberto    20   7.500000       True       3.000000
# 1        Ana    18   6.841667      False       2.736667
# 2     Camila    27   2.500000      False       1.000000
# 3      David    18   5.000000      False       2.000000
# 4      Brian    21  10.000000       True       4.000000
# 5      Bruna    23   6.841667      False       2.736667
# 6    Daniela    21   7.000000       True       2.800000
# 9     Victor    28   6.841667      False       2.736667
# 10    Danilo    21   6.841667      False       2.736667
# 11   Ignacio    24   4.500000      False       1.800000
# 12  Stephany    26  10.000000       True       4.000000
# 13    Miriam    25   9.000000       True       3.600000
# 14     Pablo    37   6.841667      False       2.736667
# 15    Milena    29   7.000000       True       2.800000
# 16     Lucas    33   6.841667      False       2.736667
# 17     Nadia    34   8.000000  Verdadero       3.200000

# %%
alumnos['Aprobado'] = alumnos['Aprobado'].replace('Verdadero', True)

# %% [markdown]
# ###Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.

# %%
df_notas_finales = np.minumin alumnos['Nota'] + alumnos['Puntos_extras']
df_notas_finales
# Out:
# 0     10.500000
# 1      9.578333
# 2      3.500000
# 3      7.000000
# 4     14.000000
# 5      9.578333
# 6      9.800000
# 9      9.578333
# 10     9.578333
# 11     6.300000
# 12    14.000000
# 13    12.600000
# 14     9.578333
# 15     9.800000
# 16     9.578333
# 17    11.200000
# dtype: float64

# %%
#Usando el metodo minimum de Numpy, para colocar un maximo de notas

import numpy as np

alumnos['Notas_finales'] = np.minimum(alumnos['Nota'] + alumnos['Puntos_extras'],10)
alumnos
# Out:
#       Nombre  Edad       Nota Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.500000     True       3.000000      10.000000
# 1        Ana    18   6.841667    False       2.736667       9.578333
# 2     Camila    27   2.500000    False       1.000000       3.500000
# 3      David    18   5.000000    False       2.000000       7.000000
# 4      Brian    21  10.000000     True       4.000000      10.000000
# 5      Bruna    23   6.841667    False       2.736667       9.578333
# 6    Daniela    21   7.000000     True       2.800000       9.800000
# 9     Victor    28   6.841667    False       2.736667       9.578333
# 10    Danilo    21   6.841667    False       2.736667       9.578333
# 11   Ignacio    24   4.500000    False       1.800000       6.300000
# 12  Stephany    26  10.000000     True       4.000000      10.000000
# 13    Miriam    25   9.000000     True       3.600000      10.000000
# 14     Pablo    37   6.841667    False       2.736667       9.578333
# ...

# %%
#Usando el metodo clip, para colocar un maximo de notas.

alumnos['Notas_finales'] = (alumnos['Nota'] + alumnos['Puntos_extras']).clip(upper=10)
alumnos
# Out:
#       Nombre  Edad       Nota  Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.500000      True       3.000000      10.000000
# 1        Ana    18   6.841667     False       2.736667       9.578333
# 2     Camila    27   2.500000     False       1.000000       3.500000
# 3      David    18   5.000000     False       2.000000       7.000000
# 4      Brian    21  10.000000      True       4.000000      10.000000
# 5      Bruna    23   6.841667     False       2.736667       9.578333
# 6    Daniela    21   7.000000      True       2.800000       9.800000
# 9     Victor    28   6.841667     False       2.736667       9.578333
# 10    Danilo    21   6.841667     False       2.736667       9.578333
# 11   Ignacio    24   4.500000     False       1.800000       6.300000
# 12  Stephany    26  10.000000      True       4.000000      10.000000
# 13    Miriam    25   9.000000      True       3.600000      10.000000
# ...

# %% [markdown]
# ###3. Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
#
# False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

# %%
alumnos['Aprobado_final'] = alumnos['Notas_finales'] >= 7
alumnos
# Out:
#       Nombre  Edad       Nota Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.500000     True       3.000000      10.000000
# 1        Ana    18   6.841667    False       2.736667       9.578333
# 2     Camila    27   2.500000    False       1.000000       3.500000
# 3      David    18   5.000000    False       2.000000       7.000000
# 4      Brian    21  10.000000     True       4.000000      10.000000
# 5      Bruna    23   6.841667    False       2.736667       9.578333
# 6    Daniela    21   7.000000     True       2.800000       9.800000
# 9     Victor    28   6.841667    False       2.736667       9.578333
# 10    Danilo    21   6.841667    False       2.736667       9.578333
# 11   Ignacio    24   4.500000    False       1.800000       6.300000
# 12  Stephany    26  10.000000     True       4.000000      10.000000
# 13    Miriam    25   9.000000     True       3.600000      10.000000
# 14     Pablo    37   6.841667    False       2.736667       9.578333
# ...

# %% [markdown]
# ###Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          16 non-null     object
#  1   Edad            16 non-null     int64
#  2   Nota            16 non-null     float64
#  3   Aprobado        16 non-null     object
#  4   Puntos_extras   16 non-null     float64
#  5   Notas_finales   16 non-null     float64
#  6   Aprobado_final  16 non-null     bool
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 912.0+ bytes

# %%
# Corregir "Verdadero" a True y "Falso" a False en la columna 'Aprobado'
alumnos['Aprobado'] = alumnos['Aprobado'].replace({'True': True, 'False': False, 'Verdadero': True})

# Convertir la columna 'Aprobado' al tipo booleano
alumnos['Aprobado'] = alumnos['Aprobado'].astype(bool)

# Realizar la consulta para encontrar los alumnos "reaprobados"
alumnos_reaprobados = alumnos.query('Aprobado == False & Aprobado_final == True')
alumnos_reaprobados
# Out:
#     Nombre  Edad      Nota  Aprobado  Puntos_extras  Notas_finales  \
# 1      Ana    18  6.841667     False       2.736667       9.578333
# 3    David    18  5.000000     False       2.000000       7.000000
# 5    Bruna    23  6.841667     False       2.736667       9.578333
# 9   Victor    28  6.841667     False       2.736667       9.578333
# 10  Danilo    21  6.841667     False       2.736667       9.578333
# 14   Pablo    37  6.841667     False       2.736667       9.578333
# 16   Lucas    33  6.841667     False       2.736667       9.578333
#
#     Aprobado_final
# 1             True
# 3             True
# 5             True
# 9             True
# 10            True
# 14            True
# 16            True
